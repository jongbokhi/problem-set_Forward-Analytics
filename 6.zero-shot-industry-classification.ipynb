# %%
import numpy as np
import pandas as pd 
import torch
from transformers import pipeline
from sklearn.metrics import accuracy_score

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"
device
# Out:
# 'cuda'

# %%
# Load dataset
df = pd.read_csv("/kaggle/input/preprocessedcompany/mapped_company")

# %%
# Sampling 500 points
sampled_df = df.sample(n=500, random_state=42)

# %%
sampled_df = sampled_df[['NAME_CLEANED', 'INDUSTRY_GROUP']]
sampled_df.head()
# Out:
#                                        NAME_CLEANED  \
# 15491963                              bc decorators
# 7238198   bms baustelleneinrichtungen detlef wenzig
# 13339616                            dynamic masonry
# 6791797                            ingeytec oficina
# 15360571                               johnson bros
#
#                       INDUSTRY_GROUP
# 15491963  Construction & Real Estate
# 7238198                        Other
# 13339616  Construction & Real Estate
# 6791797   Construction & Real Estate
# 15360571     Retail & Consumer Goods

# %%
candidate_labels = sampled_df['INDUSTRY_GROUP'].unique()
candidate_labels
# Out:
# array(['Construction & Real Estate', 'Other', 'Retail & Consumer Goods',
#        'Technology & IT', 'Media, Entertainment & Arts', 'Energy',
#        'Food & Hospitality', 'Legal', 'Education & Training',
#        'Government & Non-Profit', 'Resources', 'Business Services',
#        'Manufacturing & Engineering', 'Finance',
#        'Transportation & Logistics', 'Healthcare & Wellness',
#        'Environmental Services & Agriculture'], dtype=object)

# %%
# Initialize the classifier
classifier = pipeline("zero-shot-classification", model="facebook/bart-large-mnli", device=device)
# Out:
# /opt/conda/lib/python3.10/site-packages/transformers/tokenization_utils_base.py:1617: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be deprecated in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(

# %%
# Function to make predictions and calculate accuracy
def predict_and_evaluate(df, classifier, target, text, candidate_labels):
    # Predict industry group for each NAME_CLEANED
    predictions = []
    for name in df[text]:
        result = classifier(name, candidate_labels=candidate_labels)
        # Get the label with the highest score
        predicted_label = result['labels'][0]
        predictions.append(predicted_label)
    
    # Add predictions to the DataFrame
    df['PREDICTED_GROUP'] = predictions
    
    # Calculate accuracy
    accuracy = accuracy_score(df[target], df['PREDICTED_GROUP'])
    return df, accuracy

# %%
df, accuracy = predict_and_evaluate(df=sampled_df,
                                    classifier=classifier,
                                    target='INDUSTRY_GROUP',
                                    text='NAME_CLEANED',
                                    candidate_labels = candidate_labels)

# %%
# Output results
df.head(30)
# Out:
#                                                NAME_CLEANED  \
# 15491963                                      bc decorators
# 7238198           bms baustelleneinrichtungen detlef wenzig
# 13339616                                    dynamic masonry
# 6791797                                    ingeytec oficina
# 15360571                                       johnson bros
# 6322572                                              itechx
# 2401577                                         droneascent
# 7005558                            smart drilling solutions
# 14114035                                      rei das bicas
# 15500313                                     white  subways
# 3336493                                              orphio
# 5729535                                         psychicprod
# 8897335                                     harvard  prelaw
# 11696032       cambridge university mixed martial arts team
# 13319068                                  rbalance coaching
# 11199428                                             marion
# 18106854                                          ay amparo
# 12010870                                     subhang capsas
# 10690482                       consultant agency management
# 8322183                                         ecomfy lead
# 3165601                                               veith
# 13454350                                            deck 21
# 15790724                                 howgate restaurant
# 16370794                                   tall story games
# 11171476                                        faktomexico
# 15046822                                            addlane
# 14559436                             nexen finance 2014 ulc
# 14213310                               college louis durand
# 6048009                                advocacia flor  maio
# 777980    societe departementale des transports du var s...
#
#                        INDUSTRY_GROUP              PREDICTED_GROUP
# 15491963   Construction & Real Estate            Business Services
# 7238198                         Other            Business Services
# 13339616   Construction & Real Estate                        Legal
# 6791797    Construction & Real Estate                       Energy
# 15360571      Retail & Consumer Goods                        Legal
# 6322572               Technology & IT              Technology & IT
# 2401577   Media, Entertainment & Arts              Technology & IT
# 7005558                        Energy                    Resources
# 14114035   Construction & Real Estate                    Resources
# 15500313           Food & Hospitality                        Other
# 3336493   Media, Entertainment & Arts                        Other
# 5729535   Media, Entertainment & Arts                        Other
# 8897335                         Legal                        Legal
# 11696032                        Other  Media, Entertainment & Arts
# 13319068         Education & Training                    Resources
# 11199428      Government & Non-Profit                        Other
# 18106854                        Other                        Other
# 12010870                    Resources                        Other
# 10690482            Business Services                        Legal
# 8322183                         Other                       Energy
# 3165601   Manufacturing & Engineering                       Energy
# 13454350           Food & Hospitality                        Other
# 15790724           Food & Hospitality           Food & Hospitality
# 16370794                        Other  Media, Entertainment & Arts
# 11171476                      Finance                        Other
# 15046822              Technology & IT                        Other
# 14559436                       Energy                      Finance
# 14213310                        Other                        Legal
# 6048009                         Legal                      Finance
# 777980     Transportation & Logistics   Transportation & Logistics

# %%
print(f"\nOverall Accuracy: {accuracy:.3%}")
# Out:
# Overall Accuracy: 24.200%
